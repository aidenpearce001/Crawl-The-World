# %%
import requests

# %%
url = "https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%221111522964%22%2C%22count%22%3A20%2C%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D"
cursorScroll = "%22cursor%22%3A%22{}%3D%3D%22%2C"
payload={}
headers = {
  'authority': 'twitter.com',
  'pragma': 'no-cache',
  'cache-control': 'no-cache',
  'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"',
  'x-twitter-client-language': 'en',
  'x-csrf-token': '79e0b80290a7f537af1b4a2b99b0575720c4789d4de7cce8772879ede9afa89b3abc2812831fad862759a67ee86678509fa40323cb3ecff7964e2dafc310477c8c02952507cd24446b80f288370cb6d3',
  'sec-ch-ua-mobile': '?0',
  'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
  'content-type': 'application/json',
  'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36',
  'x-twitter-auth-type': 'OAuth2Session',
  'x-twitter-active-user': 'yes',
  'accept': '*/*',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-mode': 'cors',
  'sec-fetch-dest': 'empty',
  'referer': 'https://twitter.com/cr3d1tc4rds?lang=en',
  'accept-language': 'en-US,en;q=0.9',
  'cookie': 'personalization_id="v1_y97XRD8U6+z8IFm/OaJfgw=="; guest_id=v1%3A160265453282137688; auth_token=7f8b128c88da1dde4a591ce0240c8da630b824fb; twid=u%3D1316255073391923200; ct0=79e0b80290a7f537af1b4a2b99b0575720c4789d4de7cce8772879ede9afa89b3abc2812831fad862759a67ee86678509fa40323cb3ecff7964e2dafc310477c8c02952507cd24446b80f288370cb6d3; _ga=GA1.2.2128822207.1619099685; _gid=GA1.2.1261501825.1622466028; mbox=session#22a93545db18490580c001dee0b50da1#1622477991|PC#22a93545db18490580c001dee0b50da1.38_0#1685720932; lang=en; personalization_id="v1_fPgtWn8ueI3L4onBDPayTQ=="; guest_id=v1%3A162247101435083166'
}

response = requests.request("GET", url, headers=headers, data=payload).json()

# print(response)
#

# %%
user_entry = response["data"]["user"]["result"]["timeline"]["timeline"]["instructions"][0]["entries"]

# %%
user_entry[-1]
# Out:
# {'entryId': 'cursor-bottom-862287557299720191',
#  'sortIndex': '862287557299720191',
#  'content': {'entryType': 'TimelineTimelineCursor',
#   'value': 'HBaAwLax3/269xcAAA==',
#   'cursorType': 'Bottom',
#   'stopOnEmptyResponse': True}}

# %%
len(user_entry)
# Out:
# 22

# %%
entities = user_entry[4]["content"]["itemContent"]["tweet"]["legacy"]["retweeted_status"]

# %%
entities["legacy"]["entities"]
# Out:
# {'media': [{'display_url': 'pic.twitter.com/bhkFUWkE1K',
#    'expanded_url': 'https://twitter.com/MarkyMac/status/897277810527621125/photo/1',
#    'id_str': '897277744794411008',
#    'indices': [45, 68],
#    'media_url_https': 'https://pbs.twimg.com/media/DHPFWttVoAAIrXd.jpg',
#    'type': 'photo',
#    'url': 'https://t.co/bhkFUWkE1K',
#    'features': {'large': {'faces': [{'x': 915, 'y': 1125, 'h': 75, 'w': 75},
#       {'x': 453, 'y': 747, 'h': 187, 'w': 187}]},
#     'medium': {'faces': [{'x': 536, 'y': 659, 'h': 44, 'w': 44},
#       {'x': 265, 'y': 438, 'h': 110, 'w': 110}]},
#     'small': {'faces': [{'x': 304, 'y': 373, 'h': 25, 'w': 25},
#       {'x': 150, 'y': 248, 'h': 62, 'w': 62}]},
#     'orig': {'faces': [{'x': 1803, 'y': 2216, 'h': 149, 'w': 149},
#       {'x': 893, 'y': 1472, 'h': 370, 'w': 370}]}},
#    'sizes': {'large': {'h': 1536, 'w': 2048, 'resize': 'fit'},
#     'medium': {'h': 900, 'w': 1200, 'resize': 'fit'},
# ...

# %%
import os

def getImgUrl(user_entry):
    imgUrl = []
    # 1 cuz zero idx means the owner of this tweet
    for idx in range(1, len(user_entry)):
        print("Get images from user {}".format(idx))
        try:
            legacy = user_entry[idx]["content"]["itemContent"]["tweet"]["legacy"]
#             print(legacy)
            print("Title: ", legacy["full_text"])
        except KeyError as e:
            print(e)
            continue
        if("entities" in legacy):
            imgUrl = getUrlFromEntity(legacy, imgUrl)
        if("retweeted_status" in legacy):
            imgUrl = getUrlFromRetweeted(legacy, imgUrl)
        
        
    return imgUrl

def getUrlFromEntity(legacy, imgUrl):
    entities = legacy["entities"]
    try:
        medias = entities["media"]
    except KeyError as e:
        return imgUrl
    
    for media in medias:
            if("media_url_https" in media):
                imgUrl.append(media["media_url_https"])
            else:
                continue
    return imgUrl

def getUrlFromRetweeted(legacy, imgUrl):
    entities = legacy["retweeted_status"]["legacy"]["entities"]
#     print(entities)
    try:
        medias = entities["media"]
    except KeyError as e:
        return imgUrl    
    for media in medias:
        if("media_url_https" in media):
            imgUrl.append(media["media_url_https"])
        else:
            continue
    return imgUrl

def downloads(url, folder):
    img_name = url.split("/")[-1]
    print("Download image ", img_name)
    img_data = requests.get(url).content
    saveFolder = os.path.join(folder, img_name)
    with open(saveFolder, 'wb') as handler:
        handler.write(img_data)
        
def downloadImgFromUrl(imgUrl):
    folder = "images"
    print("Start downloading ...")
    for url in imgUrl:
        downloads(url, folder)
    numCrawledImages = len(os.listdir(folder))
    
#     assert numCrawledImages == len(imgUrl), "Some urls wrong"
    print(f"Finish download {numCrawledImages} url")

# %%
imgUrl = getImgUrl(user_entry)
downloadImgFromUrl(imgUrl)
# Out:
# Get images from user 1
# Title:  RT @devonborder: just got a new credit card 😍😍 https://t.co/wyztooZc7Y
# Get images from user 2
# Title:  RT @DjKvo_Oficial: I have a new credit card! Thank you @PayoneerEspanol for the support! -The king, Dj Kvo https://t.co/OAtwXC8fvS
# Get images from user 3
# 'itemContent'
# Get images from user 4
# Title:  RT @YeIIowschoolbus: My new debit card!! Blue looks good https://t.co/KpsWfNWs06
# Get images from user 5
# 'legacy'
# Get images from user 6
# 'itemContent'
# Get images from user 7
# Title:  RT @ReasonablePaulM: New debit card. #excited https://t.co/qtkEkDlP5L
# Get images from user 8
# Title:  RT @attitudeswt: @radhikamadan01 @shaktiarora @ColorsTV  radhika ji check my new debit card with ur pic and show hw much I like u https://t…
# Get images from user 9
# Title:  RT @attitudeswt: @radhikamadan01 @shaktiarora @ColorsTV  radhika ji check my new debit card with ur pic and show hw much I like u https://t…
# Get images from user 10
# ...

# %%
import urllib
# debit card 
Url = "https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%22595694685%22%2C%22count%22%3A20%2C{}%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D"
startUrl = "https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%22595694685%22%2C%22count%22%3A20%2C%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D"
def getUserEntry(url):
    response = requests.request("GET", url, headers=headers, data=payload).json()
    userEntry = response["data"]["user"]["result"]["timeline"]["timeline"]["instructions"][0]["entries"]
    return userEntry
    
def crawl(url, startUrl):
    # format with bottom cursor code from prev api
    cursorScroll = "%22cursor%22%3A%22{}%3D%3D%22%2C"
    prevCursorCode = "hello"
    currentCursorCode = ""
    
    curPage = 0
    # stop when cursor code in url equals to bottom cursor code in current api
    while(prevCursorCode != currentCursorCode):
        print("Crawl image from page ", curPage)
        if(curPage):
            currentCursorCode = urllib.parse.quote(currentCursorCode)
            curCursorScroll = cursorScroll.format(currentCursorCode)
            curUrl = url.format(curCursorScroll)
        else:
            print("Start from first page")
            curUrl = startUrl
        
        print(curUrl)
        userEntry = getUserEntry(curUrl)
        prevCursorCode = currentCursorCode
        
        # last idx from userEntry is bottom cursor code dict, just takes value to -2 idx cuz cursor format is "(whatwewant)=="
        currentCursorCode = userEntry[-1]["content"]["value"][:-2]
        print("CursorCode: ", currentCursorCode)
        
        imgUrl = getImgUrl(userEntry)
        downloadImgFromUrl(imgUrl)
        print("Finish crawl from ", curPage)
        curPage += 1

        print("-" * 50)

# %%
# crawl(Url, startUrl)

# %%
Url = "https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%221111522964%22%2C{}%22count%22%3A20%2C%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D"
startUrl = "https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%221111522964%22%2C%22count%22%3A20%2C%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D"
crawl(Url, startUrl)
# Out:
# Crawl image from page  0
# Start from first page
# https://twitter.com/i/api/graphql/1DL8zlYnR-WKbi0BUG2rzQ/UserTweets?variables=%7B%22userId%22%3A%221111522964%22%2C%22count%22%3A20%2C%22withHighlightedLabel%22%3Atrue%2C%22withTweetQuoteCount%22%3Atrue%2C%22includePromotedContent%22%3Atrue%2C%22withTweetResult%22%3Afalse%2C%22withReactions%22%3Afalse%2C%22withUserResults%22%3Afalse%2C%22withVoice%22%3Afalse%2C%22withNonLegacyCard%22%3Atrue%2C%22withBirdwatchPivots%22%3Afalse%7D
# CursorCode:  HBaAwLax3/269xcAAA
# Get images from user 1
# Title:  RT @TebohoISHMAEL3: Oh shit my credit card https://t.co/LQoWMLtONR
# Get images from user 2
# Title:  RT @AydeeMaybrew: My new credit card is pink. I love it.
# Now to find money to put on it. https://t.co/MTAhp0rkRy
# Get images from user 3
# 'itemContent'
# Get images from user 4
# Title:  RT @MarkyMac: @final credit card rocks!
# Pm me for sizing! https://t.co/bhkFUWkE1K
# Get images from user 5
# 'legacy'
# Get images from user 6
# ...

# %%
urllib.parse.quote("HBaAgMO47++H2A4AAA")
# Out:
# 'HBaAgMO47%2B%2BH2A4AAA'
